# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('HomeC.csv')
df.head()
# Out:
# D:\Sanketh\Softwares\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          time  use [kW]  gen [kW]  House overall [kW]  Dishwasher [kW]  \
# 0  1451624400  0.932833  0.003483            0.932833         0.000033
# 1  1451624401  0.934333  0.003467            0.934333         0.000000
# 2  1451624402  0.931817  0.003467            0.931817         0.000017
# 3  1451624403  1.022050  0.003483            1.022050         0.000017
# 4  1451624404  1.139400  0.003467            1.139400         0.000133
#
#    Furnace 1 [kW]  Furnace 2 [kW]  Home office [kW]  Fridge [kW]  \
# 0        0.020700        0.061917          0.442633     0.124150
# 1        0.020717        0.063817          0.444067     0.124000
# 2        0.020700        0.062317          0.446067     0.123533
# ...

# %%
dsc = df.describe()
dsc = dsc.transpose()
dsc.columns
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')

# %%
dsc
# Out:
#                         count         mean         std         min  \
# use [kW]             503910.0     0.858962    1.058207    0.000000
# gen [kW]             503910.0     0.076229    0.128428    0.000000
# House overall [kW]   503910.0     0.858962    1.058207    0.000000
# Dishwasher [kW]      503910.0     0.031368    0.190951    0.000000
# Furnace 1 [kW]       503910.0     0.099210    0.169059    0.000017
# Furnace 2 [kW]       503910.0     0.136779    0.178631    0.000067
# Home office [kW]     503910.0     0.081287    0.104466    0.000083
# Fridge [kW]          503910.0     0.063556    0.076199    0.000067
# Wine cellar [kW]     503910.0     0.042137    0.057967    0.000017
# Garage door [kW]     503910.0     0.014139    0.014292    0.000017
# Kitchen 12 [kW]      503910.0     0.002755    0.021860    0.000000
# Kitchen 14 [kW]      503910.0     0.007023    0.076740    0.000000
# Kitchen 38 [kW]      503910.0     0.000009    0.000010    0.000000
# ...

# %%
dsc['mean']
# Out:
# use [kW]                  0.858962
# gen [kW]                  0.076229
# House overall [kW]        0.858962
# Dishwasher [kW]           0.031368
# Furnace 1 [kW]            0.099210
# Furnace 2 [kW]            0.136779
# Home office [kW]          0.081287
# Fridge [kW]               0.063556
# Wine cellar [kW]          0.042137
# Garage door [kW]          0.014139
# Kitchen 12 [kW]           0.002755
# Kitchen 14 [kW]           0.007023
# Kitchen 38 [kW]           0.000009
# Barn [kW]                 0.058530
# Well [kW]                 0.015642
# Microwave [kW]            0.010983
# Living room [kW]          0.035313
# Solar [kW]                0.076229
# temperature              50.741935
# humidity                  0.664085
# visibility                9.253444
# apparentTemperature      48.263382
# pressure               1016.301625
# windSpeed                 6.649936
# windBearing             202.356843
# precipIntensity           0.002598
# dewPoint                 38.694013
# ...

# %%
list1 = []
for i in range(2,18):
    list1.append(dsc['mean'][i])

# %%
plt.figure(figsize=(15,7))
listleg = ['House overall [kW]', 'Dishwasher [kW]', 'Furnace 1 [kW]', 'Furnace 2 [kW]', 'Home office [kW]', 'Fridge [kW]', 'Wine cellar [kW]', 
       'Garage door [kW]',' Kitchen 12 [kW]', 'Kitchen 14 [kW]', 'Kitchen 38 [kW]', 'Barn [kW]', 'Well [kW]', 'Microwave [kW]'
       'Living room [kW]', 'Solar [kW]']
plt.pie(list1)
plt.title('Average Power Consumption in the Household by each appliance', size = 17, weight ="bold", pad=20)
plt.legend(listleg, title ="Result", loc ="center left", bbox_to_anchor =(1.5, 0, 0.5, 0.5)) 
plt.show()

# %%
df['time']
# Out:
# 0         1451624400
# 1         1451624401
# 2         1451624402
# 3         1451624403
# 4         1451624404
#              ...
# 503906    1452128306
# 503907    1452128307
# 503908    1452128308
# 503909    1452128309
# 503910             \
# Name: time, Length: 503911, dtype: object

# %%
plt.figure(figsize=(15,7))
plt.plot(df['House overall [kW]'], df['time'], label='Household')
plt.plot(df['Dishwasher [kW]'], df['time'], label='Dish Washer')
plt.plot(df['Solar [kW]'], df['time'], label='Solar')
plt.title('Total Power Consumption in the Household compared to any two appliances', size = 17, weight ="bold", pad=20)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(df['House overall [kW]'])
plt.show()

# %% [markdown]
# # Supervised Learning

# %%
from sklearn.model_selection import train_test_split

# %%
X = df['House overall [kW]']
y = df['time']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-d768f88d541e> in <module>
# ----> 1 model.fit(X_train, y_train)
#
# D:\Sanketh\Softwares\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1340             _dtype = [np.float64, np.float32]
#    1341
# -> 1342         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1343                                    order="C",
#    1344                                    accept_large_sparse=solver != 'liblinear')
#
# D:\Sanketh\Softwares\Anaconda\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ...
